# %%
import os
import cv2

# Create the output directory if it doesn't exist
os.makedirs("/content/drive/MyDrive/Colab Notebooks/icdar_ijdar_2025/qumran_segmentation_dataset/cropped_multispectral_images", exist_ok=True)

# Read the bounding box coordinates from the file
with open("/content/drive/MyDrive/Colab Notebooks/icdar_ijdar_2025/qumran_segmentation_dataset/fragment_bbox_coordinates_for_56_items.txt", "r") as file:
    lines = file.readlines()

# Process each line to crop the corresponding image
for line in lines:
    # Parse the line to get the image filename and bounding box coordinates
    parts = line.strip().split()
    image_filename = parts[0]+".tif"
    x1, y1 = map(int, parts[1].split('-'))
    x2, y2 = map(int, parts[2].split('-'))

    # Load the image from the "color_images" folder
    image_path = os.path.join("/content/drive/MyDrive/Colab Notebooks/icdar_ijdar_2025/qumran_segmentation_dataset/multispectral_images", image_filename)
    image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)

    if image is None:
        print(f"Image {image_filename} not found.")
        continue

    # Crop the image using the bounding box coordinates
    cropped_image = image[y1:y2, x1:x2]

    # Save the cropped image to the "cropped_fullcolor_images" folder
    output_path = os.path.join("/content/drive/MyDrive/Colab Notebooks/icdar_ijdar_2025/qumran_segmentation_dataset/cropped_multispectral_images", image_filename)
    cv2.imwrite(output_path, cropped_image)

    print(f"Cropped image saved to {output_path}")
# Out:
# Cropped image saved to /content/drive/MyDrive/Colab Notebooks/icdar_ijdar_2025/qumran_segmentation_dataset/cropped_multispectral_images/124-Fg001-R-C01-R01-D10112011-T102106-LR924_012_F.tif
# Cropped image saved to /content/drive/MyDrive/Colab Notebooks/icdar_ijdar_2025/qumran_segmentation_dataset/cropped_multispectral_images/124-Fg001-R-C01-R01-D10112011-T101957-LR445_001_F.tif
# Cropped image saved to /content/drive/MyDrive/Colab Notebooks/icdar_ijdar_2025/qumran_segmentation_dataset/cropped_multispectral_images/124-Fg002-R-C01-R01-D10112011-T103406-LR924_012_F.tif
# Cropped image saved to /content/drive/MyDrive/Colab Notebooks/icdar_ijdar_2025/qumran_segmentation_dataset/cropped_multispectral_images/124-Fg002-R-C01-R01-D10112011-T103257-LR445_001_F.tif
# Cropped image saved to /content/drive/MyDrive/Colab Notebooks/icdar_ijdar_2025/qumran_segmentation_dataset/cropped_multispectral_images/124-Fg004-R-C01-R01-D10112011-T105711-LR924_012_F.tif
# ...

# %%
import os
import cv2

# Paths for input and output directories
input_dir = '/content/drive/MyDrive/Colab Notebooks/icdar_ijdar_2025/124-001'
output_dir = '/content/drive/MyDrive/Colab Notebooks/icdar_ijdar_2025/cropped_124_001'
os.makedirs(output_dir, exist_ok=True)

# Crop coordinates (y_start:y_end, x_start:x_end)
crop_coords = (2300, 5500, 900, 4000)

# Iterate through tif images in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith('.tif'):
        # Read the image
        image_path = os.path.join(input_dir, filename)
        image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)

        # Crop the image using the provided coordinates
        cropped_image = image[1000:4000, 2300:5500]

        # Create the new filename based on the band number
        band_name = filename.split('_')[-2]  # Extract the band number part
        new_filename = f"124_001_{band_name}.tif"

        # Save the cropped image
        output_path = os.path.join(output_dir, new_filename)
        cv2.imwrite(output_path, cropped_image)

# Indicate completion
output_dir
# Out:
# '/content/drive/MyDrive/Colab Notebooks/icdar_ijdar_2025/cropped_124_001'
